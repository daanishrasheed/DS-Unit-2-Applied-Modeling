# %% [markdown]
# <a href="https://colab.research.google.com/github/daanishrasheed/DS-Unit-2-Applied-Modeling/blob/master/module3/LS_DS_233_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 3*
#
# ---
#
#
# # Applied Modeling, Module 3
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your work.
#
# - [ ] Continue to iterate on your project: data cleaning, exploration, feature engineering, modeling.
# - [ ] Make at least 1 partial dependence plot to explain your model.
# - [ ] Share at least 1 visualization on Slack.
#
# (If you have not yet completed an initial model yet for your portfolio project, then do today's assignment using your Tanzania Waterpumps model.)
#
# ## Stretch Goals
# - [ ] Make multiple PDPs with 1 feature in isolation.
# - [ ] Make multiple PDPs with 2 features in interaction.
# - [ ] Use Plotly to make a 3D PDP.
# - [ ] Make PDPs with categorical feature(s). Use Ordinal Encoder, outside of a pipeline, to encode your data first. If there is a natural ordering, then take the time to encode it that way, instead of random integers. Then use the encoded data with pdpbox. Get readable category names on your plot, instead of integer category codes.
#
# ## Links
# - [Christoph Molnar: Interpretable Machine Learning — Partial Dependence Plots](https://christophm.github.io/interpretable-ml-book/pdp.html) + [animated explanation](https://twitter.com/ChristophMolnar/status/1066398522608635904)
# - [Kaggle / Dan Becker: Machine Learning Explainability — Partial Dependence Plots](https://www.kaggle.com/dansbecker/partial-plots)
# - [Plotly: 3D PDP example](https://plot.ly/scikit-learn/plot-partial-dependence/#partial-dependence-of-house-value-on-median-age-and-average-occupancy)

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
    # !pip install category_encoders==2.*
    # !pip install eli5
    # !pip install pdpbox

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-991bf001-f3ae-4faa-9b5b-1e62e398cea5" name="files[]" multiple disabled />
#      <output id="result-991bf001-f3ae-4faa-9b5b-1e62e398cea5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
play = pd.read_csv('pbp-2018.csv', engine='python')
print(play.shape)
play.head()
# Out:
# (45016, 45)
#        GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 0  2018090600  2018-09-06        2  ...         0          NaN            0
# 1  2018090600  2018-09-06        2  ...         0          NaN            0
# 2  2018090600  2018-09-06        3  ...         0          NaN            0
# 3  2018090600  2018-09-06        4  ...         0          NaN            0
# 4  2018090600  2018-09-06        4  ...         0          NaN            0
#
# [5 rows x 45 columns]

# %%
play = play.drop(play[play.Down == 0].index)

# %%
play.head()
# Out:
#         GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 15  2018090903  2018-09-09        4  ...         0          NaN            0
# 22  2018090908  2018-09-09        2  ...         0          NaN            0
# 24  2018090909  2018-09-09        3  ...         0          NaN            0
# 34  2018091000  2018-09-10        3  ...         0          NaN            0
# 35  2018091000  2018-09-10        3  ...         0          NaN            0
#
# [5 rows x 45 columns]

# %%
df = play.drop(columns=['Unnamed: 10', 'Unnamed: 12', 'Unnamed: 16', 'Unnamed: 17', 'Challenger'])

# %%
df.tail(5)
# Out:
#            GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 45011  2018123015  2018-12-30        4  ...         0          NaN            0
# 45012  2018123015  2018-12-30        4  ...         0          NaN            0
# 45013  2018123015  2018-12-30        4  ...         0          NaN            0
# 45014  2018123015  2018-12-30        4  ...         0          NaN            0
# 45015  2018123015  2018-12-30        4  ...         0          NaN            0
#
# [5 rows x 40 columns]

# %%
df1 = df.drop(df[(df.IsRush == 1) & (df.IsPass == 1)].index)

# %%
df1.head(10)
# Out:
#         GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 15  2018090903  2018-09-09        4  ...         0          NaN            0
# 22  2018090908  2018-09-09        2  ...         0          NaN            0
# 24  2018090909  2018-09-09        3  ...         0          NaN            0
# 34  2018091000  2018-09-10        3  ...         0          NaN            0
# 35  2018091000  2018-09-10        3  ...         0          NaN            0
# 42  2018091601  2018-09-16        1  ...         0          NaN            0
# 43  2018091601  2018-09-16        3  ...         0          NaN            0
# 47  2018091603  2018-09-16        4  ...         0          NaN            0
# 48  2018091604  2018-09-16        1  ...         0          NaN            0
# 55  2018091608  2018-09-16        2  ...         0          NaN            0
#
# [10 rows x 40 columns]

# %%
df = df1.drop(df1[df1.PlayType == 'QB KNEEL'].index)

# %%
df.head()
# Out:
#         GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 22  2018090908  2018-09-09        2  ...         0          NaN            0
# 24  2018090909  2018-09-09        3  ...         0          NaN            0
# 34  2018091000  2018-09-10        3  ...         0          NaN            0
# 35  2018091000  2018-09-10        3  ...         0          NaN            0
# 42  2018091601  2018-09-16        1  ...         0          NaN            0
#
# [5 rows x 40 columns]

# %%
df['PlayType'].value_counts()
# Out:
# PASS          18490
# RUSH          12173
# PUNT           2294
# SACK           1370
# FIELD GOAL      948
# SCRAMBLE        826
# NO PLAY         826
# FUMBLES          85
# CLOCK STOP       78
# EXCEPTION        55
# PENALTY           2
# Name: PlayType, dtype: int64

# %%
df['Formation'].value_counts()
# Out:
# SHOTGUN              19582
# UNDER CENTER         11786
# PUNT                  2215
# NO HUDDLE SHOTGUN     2065
# FIELD GOAL             948
# NO HUDDLE              576
# WILDCAT                  1
# Name: Formation, dtype: int64

# %%
df = df.drop(df[df.Formation == 'PUNT'].index)
df = df.drop(df[df.PlayType == 'PUNT'].index)
df = df.drop(df[df.Formation == 'FIELD GOAL'].index)
df = df.drop(df[df.PlayType == 'FIELD GOAL'].index)

# %%
df.head()
# Out:
#         GameId    GameDate  Quarter  ...  IsNoPlay  PenaltyType PenaltyYards
# 22  2018090908  2018-09-09        2  ...         0          NaN            0
# 24  2018090909  2018-09-09        3  ...         0          NaN            0
# 34  2018091000  2018-09-10        3  ...         0          NaN            0
# 35  2018091000  2018-09-10        3  ...         0          NaN            0
# 42  2018091601  2018-09-16        1  ...         0          NaN            0
#
# [5 rows x 40 columns]

# %%
df['PlayType'].value_counts()
# Out:
# PASS          18489
# RUSH          12173
# SACK           1370
# SCRAMBLE        826
# NO PLAY         826
# FUMBLES          85
# CLOCK STOP       78
# EXCEPTION        55
# PENALTY           2
# Name: PlayType, dtype: int64

# %%
df = df.drop(df[df.PlayType == 'NO PLAY'].index)
df = df.drop(df[df.PlayType == 'FUMBLES'].index)
df = df.drop(df[df.PlayType == 'CLOCK STOP'].index)
df = df.drop(df[df.PlayType == 'EXCEPTION'].index)
df = df.drop(df[df.PlayType == 'PENALTY'].index)

# %%
df = df.replace('SACK', 'PASS')
df = df.replace('SCRAMBLE', 'RUSH')

# %%
df['Formation'].head(20)
# Out:
# 22              SHOTGUN
# 24         UNDER CENTER
# 34              SHOTGUN
# 35    NO HUDDLE SHOTGUN
# 42              SHOTGUN
# 43         UNDER CENTER
# 48         UNDER CENTER
# 55         UNDER CENTER
# 58            NO HUDDLE
# 62         UNDER CENTER
# 65         UNDER CENTER
# 66              SHOTGUN
# 71              SHOTGUN
# 75         UNDER CENTER
# 85              SHOTGUN
# 86              SHOTGUN
# 87              SHOTGUN
# 88              SHOTGUN
# 89              SHOTGUN
# 92         UNDER CENTER
# Name: Formation, dtype: object

# %%
df.iloc[19582]
# Out:
# GameId                                                                   2018090908
# GameDate                                                                 2018-09-09
# Quarter                                                                           2
# Minute                                                                           10
# Second                                                                           14
# OffenseTeam                                                                     LAC
# DefenseTeam                                                                      KC
# Down                                                                              2
# ToGo                                                                             10
# YardLine                                                                         66
# SeriesFirstDown                                                                   0
# NextScore                                                                         0
# Description                       (10:14) 30-A.EKELER UP THE MIDDLE TO KC 25 FOR...
# TeamWin                                                                           0
# SeasonYear                                                                     2018
# Yards                                                                             9
# Formation                                                              UNDER CENTER
# PlayType                                                                       RUSH
# IsRush                                                                            1
# IsPass                                                                            0
# IsIncomplete                                                                      0
# IsTouchdown                                                                       0
# PassType                                                                        NaN
# IsSack                                                                            0
# IsChallenge                                                                       0
# IsChallengeReversed                                                               0
# IsMeasurement                                                                     0
# IsInterception                                                                    0
# IsFumble                                                                          0
# IsPenalty                                                                         0
# IsTwoPointConversion                                                              0
# IsTwoPointConversionSuccessful                                                    0
# RushDirection                                                                CENTER
# YardLineFixed                                                                    34
# YardLineDirection                                                               OPP
# IsPenaltyAccepted                                                                 0
# PenaltyTeam                                                                     NaN
# IsNoPlay                                                                          0
# PenaltyType                                                                     NaN
# PenaltyYards                                                                      0
# Name: 28499, dtype: object

# %%
df.head(13345)
# Out:
#            GameId    GameDate  ...        PenaltyType  PenaltyYards
# 22     2018090908  2018-09-09  ...                NaN             0
# 24     2018090909  2018-09-09  ...                NaN             0
# 34     2018091000  2018-09-10  ...                NaN             0
# 35     2018091000  2018-09-10  ...                NaN             0
# 42     2018091601  2018-09-16  ...                NaN             0
# ...           ...         ...  ...                ...           ...
# 19581  2018112600  2018-11-26  ...                NaN             0
# 19582  2018112600  2018-11-26  ...                NaN             0
# 19584  2018112600  2018-11-26  ...                NaN             0
# 19586  2018112600  2018-11-26  ...  OFFENSIVE HOLDING            10
# 19587  2018112600  2018-11-26  ...                NaN             0
#
# [13345 rows x 40 columns]

# %%
values = {'PlayType':'RUSH'}
df = df.fillna(value=values)

# %%
df['Formation play'] = df[['Formation', 'PlayType']].apply(lambda x: ' '.join(x), axis=1)

# %%
df = df.drop(df[df.Formation == 'WILDCAT'].index)

# %%
df.head()
# Out:
#         GameId    GameDate  ...  PenaltyYards          Formation play
# 22  2018090908  2018-09-09  ...             0            SHOTGUN RUSH
# 24  2018090909  2018-09-09  ...             0       UNDER CENTER RUSH
# 34  2018091000  2018-09-10  ...             0            SHOTGUN PASS
# 35  2018091000  2018-09-10  ...             0  NO HUDDLE SHOTGUN PASS
# 42  2018091601  2018-09-16  ...             0            SHOTGUN PASS
#
# [5 rows x 41 columns]

# %%
df['GameDate']= pd.to_datetime(df['GameDate'])

# %%
test = df[((df.GameDate.dt.month == 12)) & ((df.GameDate.dt.day ==22) | (df.GameDate.dt.day == 23) | (df.GameDate.dt.day == 24) | (df.GameDate.dt.day == 30))]

# %%
test.head()
# Out:
#          GameId   GameDate  ...  PenaltyYards     Formation play
# 162  2018123000 2018-12-30  ...             0       SHOTGUN RUSH
# 163  2018123000 2018-12-30  ...             0       SHOTGUN RUSH
# 485  2018123000 2018-12-30  ...             0  UNDER CENTER RUSH
# 486  2018123000 2018-12-30  ...             0       SHOTGUN PASS
# 487  2018123000 2018-12-30  ...             0       SHOTGUN PASS
#
# [5 rows x 41 columns]

# %%
train = df[(df.GameDate.dt.month == 9) | (df.GameDate.dt.month == 10) | (((df.GameDate.dt.month == 11)) & ((df.GameDate.dt.day == 5) | (df.GameDate.dt.day == 4) | (df.GameDate.dt.day == 1) | (df.GameDate.dt.day == 11) | (df.GameDate.dt.day == 12) | (df.GameDate.dt.day == 8)))]

# %%
train.head()
# Out:
#         GameId   GameDate  ...  PenaltyYards          Formation play
# 22  2018090908 2018-09-09  ...             0            SHOTGUN RUSH
# 24  2018090909 2018-09-09  ...             0       UNDER CENTER RUSH
# 34  2018091000 2018-09-10  ...             0            SHOTGUN PASS
# 35  2018091000 2018-09-10  ...             0  NO HUDDLE SHOTGUN PASS
# 42  2018091601 2018-09-16  ...             0            SHOTGUN PASS
#
# [5 rows x 41 columns]

# %%
val = df[(((df.GameDate.dt.month == 11)) & ((df.GameDate.dt.day == 18) | (df.GameDate.dt.day == 22) | (df.GameDate.dt.day == 29) | (df.GameDate.dt.day == 25) | (df.GameDate.dt.day == 15) | (df.GameDate.dt.day == 19) | (df.GameDate.dt.day == 26)) | ((df.GameDate.dt.month == 12)) & ((df.GameDate.dt.day == 9) | (df.GameDate.dt.day == 16) | (df.GameDate.dt.day == 2) | (df.GameDate.dt.day == 3) | (df.GameDate.dt.day == 10) | (df.GameDate.dt.day == 17) | (df.GameDate.dt.day == 15) | (df.GameDate.dt.day == 13) | (df.GameDate.dt.day == 6)))]

# %%
val.head()
# Out:
#          GameId   GameDate  ...  PenaltyYards     Formation play
# 483  2018111500 2018-11-15  ...             0  UNDER CENTER RUSH
# 498  2018111801 2018-11-18  ...             0     NO HUDDLE RUSH
# 499  2018111801 2018-11-18  ...             0  UNDER CENTER PASS
# 505  2018111802 2018-11-18  ...             0       SHOTGUN PASS
# 506  2018111802 2018-11-18  ...             0  UNDER CENTER RUSH
#
# [5 rows x 41 columns]

# %%
target = 'Formation play'
features = ['Quarter', 'Minute', 'Second', 'OffenseTeam', 'DefenseTeam', 'Down', 'ToGo', 'YardLine', 'Formation play']

# %%
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]

# %%
X_val.head()
# Out:
#      Quarter  Minute  Second  ... ToGo YardLine     Formation play
# 483        1       9      56  ...   10       62  UNDER CENTER RUSH
# 498        1      14      22  ...    2       32     NO HUDDLE RUSH
# 499        2       7      56  ...    2       73  UNDER CENTER PASS
# 505        1      15       0  ...   10       25       SHOTGUN PASS
# 506        1      14      26  ...    2       33  UNDER CENTER RUSH
#
# [5 rows x 9 columns]

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline


pipeline = make_pipeline(
    ce.OneHotEncoder(use_cat_names=True), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=4, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_train)
print('Validation Accuracy', pipeline.score(X_val, y_val))
# Out:
# Validation Accuracy 1.0
# CPU times: user 3.69 s, sys: 202 ms, total: 3.9 s
# Wall time: 3.05 s

# %%
from xgboost import XGBClassifier

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    XGBClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['OffenseTeam', 'DefenseTeam',
#                                       'Formation play'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'OffenseTeam',
#                                           'data_type': dtype('O'),
#                                           'mapping': KC      1
# ARI     2
# DET     3
# BUF     4
# MIA     5
# WAS     6
# LA      7
# JAX     8
# NYG     9
# NYJ    10
# ATL    11
# TEN    12
# SF     13
# OAK    14
# SEA    15
# TB     16
# CHI    17
# CLE    18
# PIT    19
# BAL    20
# DEN    21
# PHI    22
# DAL    23
# NO     24
# CI...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=-1, nthread=None,
#                                objective='multi:softprob', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)

# %%
encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

m = XGBClassifier(
    n_estimators=1000, # <= 1000 trees, depends on early stopping
    max_depth=7,       # try deeper trees because of high cardinality categoricals
    learning_rate=0.5, # try higher learning rate
    n_jobs=-1
)

eval_set = [(X_train_encoded, y_train), 
            (X_val_encoded, y_val)]

model.fit(X_train_encoded, y_train, 
          eval_set=eval_set, 
          eval_metric='merror', 
          early_stopping_rounds=50)
# Out:
# [0]	validation_0-merror:0	validation_1-merror:0
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 50 rounds.
# [1]	validation_0-merror:0	validation_1-merror:0
# [2]	validation_0-merror:0	validation_1-merror:0
# [3]	validation_0-merror:0	validation_1-merror:0
# [4]	validation_0-merror:0	validation_1-merror:0
# [5]	validation_0-merror:0	validation_1-merror:0
# [6]	validation_0-merror:0	validation_1-merror:0
# [7]	validation_0-merror:0	validation_1-merror:0
# [8]	validation_0-merror:0	validation_1-merror:0
# [9]	validation_0-merror:0	validation_1-merror:0
# [10]	validation_0-merror:0	validation_1-merror:0
# [11]	validation_0-merror:0	validation_1-merror:0
# [12]	validation_0-merror:0	validation_1-merror:0
# [13]	validation_0-merror:0	validation_1-merror:0
# [14]	validation_0-merror:0	validation_1-merror:0
# [15]	validation_0-merror:0	validation_1-merror:0
# [16]	validation_0-merror:0	validation_1-merror:0
# [17]	validation_0-merror:0	validation_1-merror:0
# [18]	validation_0-merror:0	validation_1-merror:0
# [19]	validation_0-merror:0	validation_1-merror:0
# [20]	validation_0-merror:0	validation_1-merror:0
# [21]	validation_0-merror:0	validation_1-merror:0
# [22]	validation_0-merror:0	validation_1-merror:0
# [23]	validation_0-merror:0	validation_1-merror:0
# [24]	validation_0-merror:0	validation_1-merror:0
# [25]	validation_0-merror:0	validation_1-merror:0
# [26]	validation_0-merror:0	validation_1-merror:0
# [27]	validation_0-merror:0	validation_1-merror:0
# [28]	validation_0-merror:0	validation_1-merror:0
# [29]	validation_0-merror:0	validation_1-merror:0
# [30]	validation_0-merror:0	validation_1-merror:0
# [31]	validation_0-merror:0	validation_1-merror:0
# [32]	validation_0-merror:0	validation_1-merror:0
# [33]	validation_0-merror:0	validation_1-merror:0
# [34]	validation_0-merror:0	validation_1-merror:0
# [35]	validation_0-merror:0	validation_1-merror:0
# [36]	validation_0-merror:0	validation_1-merror:0
# [37]	validation_0-merror:0	validation_1-merror:0
# [38]	validation_0-merror:0	validation_1-merror:0
# [39]	validation_0-merror:0	validation_1-merror:0
# [40]	validation_0-merror:0	validation_1-merror:0
# [41]	validation_0-merror:0	validation_1-merror:0
# [42]	validation_0-merror:0	validation_1-merror:0
# [43]	validation_0-merror:0	validation_1-merror:0
# [44]	validation_0-merror:0	validation_1-merror:0
# [45]	validation_0-merror:0	validation_1-merror:0
# [46]	validation_0-merror:0	validation_1-merror:0
# [47]	validation_0-merror:0	validation_1-merror:0
# [48]	validation_0-merror:0	validation_1-merror:0
# [49]	validation_0-merror:0	validation_1-merror:0
# [50]	validation_0-merror:0	validation_1-merror:0
# Stopping. Best iteration:
# [0]	validation_0-merror:0	validation_1-merror:0
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.5, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
feature = 'Formation play'
X_val[feature].head()
# Out:
# 483    UNDER CENTER RUSH
# 498       NO HUDDLE RUSH
# 499    UNDER CENTER PASS
# 505         SHOTGUN PASS
# 506    UNDER CENTER RUSH
# Name: Formation play, dtype: object

# %%
X_val[feature].value_counts()
# Out:
# SHOTGUN PASS              4209
# UNDER CENTER RUSH         2314
# SHOTGUN RUSH              1509
# UNDER CENTER PASS         1103
# NO HUDDLE SHOTGUN PASS     418
# NO HUDDLE SHOTGUN RUSH      90
# NO HUDDLE RUSH              80
# NO HUDDLE PASS              68
# Name: Formation play, dtype: int64

# %%
import numpy as np

X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

# %%
X_val_permuted[feature].head()
# Out:
# 483       NO HUDDLE RUSH
# 498    UNDER CENTER RUSH
# 499         SHOTGUN PASS
# 505    UNDER CENTER RUSH
# 506         SHOTGUN PASS
# Name: Formation play, dtype: object

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72

# %%
X = df[features]
y = df[target]

# Use Ordinal Encoder, outside of a pipeline
encoder = ce.OrdinalEncoder()
X_encoded = encoder.fit_transform(X)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_encoded, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pdpbox import pdp
feature = 'Formation play'
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_encoded, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature);
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
