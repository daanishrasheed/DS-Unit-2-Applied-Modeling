# %% [markdown]
# <a href="https://colab.research.google.com/github/daanishrasheed/DS-Unit-2-Applied-Modeling/blob/master/DS_Sprint_Challenge_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science, Unit 2_
#
# # Applied Modeling Sprint Challenge: Predict Chicago food inspections 🍔

# %% [markdown]
# For this Sprint Challenge, you'll use a dataset with information from inspections of restaurants and other food establishments in Chicago from January 2010 to March 2019.
#
# [See this PDF](https://data.cityofchicago.org/api/assets/BAD5301B-681A-4202-9D25-51B2CAE672FF) for descriptions of the data elements included in this dataset.
#
# According to [Chicago Department of Public Health — Food Protection Services](https://www.chicago.gov/city/en/depts/cdph/provdrs/healthy_restaurants/svcs/food-protection-services.html), "Chicago is home to 16,000 food establishments like restaurants, grocery stores, bakeries, wholesalers, lunchrooms, mobile food vendors and more. Our business is food safety and sanitation with one goal, to prevent the spread of food-borne disease. We do this by inspecting food businesses, responding to complaints and food recalls."

# %% [markdown]
# #### Your challenge: Predict whether inspections failed
#
# The target is the `Fail` column.
#
# - When the food establishment failed the inspection, the target is `1`.
# - When the establishment passed, the target is `0`.

# %% [markdown]
# #### Run this cell to install packages in Colab:

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    # Install packages in Colab
    # !pip install category_encoders==2.*
    # !pip install eli5
    # !pip install pandas-profiling==2.*
    # !pip install pdpbox
    # !pip install shap

# %% [markdown]
# #### Run this cell to load the data:

# %%
import pandas as pd

train_url = 'https://drive.google.com/uc?export=download&id=13_tP9JpLcZHSPVpWcua4t2rY44K_s4H5'
test_url  = 'https://drive.google.com/uc?export=download&id=1GkDHjsiGrzOXoF_xcYjdzBTSjOIi3g5a'

train = pd.read_csv(train_url)
test  = pd.read_csv(test_url)

assert train.shape == (51916, 17)
assert test.shape  == (17306, 17)

# %% [markdown]
# ### Part 1: Preprocessing
#
# You may choose which features you want to use, and whether/how you will preprocess them. If you use categorical features, you may use any tools and techniques for encoding.
#
# _To earn a score of 3 for this part, find and explain leakage. The dataset has a feature that will give you an ROC AUC score > 0.90 if you process and use the feature. Find the leakage and explain why the feature shouldn't be used in a real-world model to predict the results of future inspections._
#
# ### Part 2: Modeling
#
# **Fit a model** with the train set. (You may use scikit-learn, xgboost, or any other library.) Use cross-validation or do a three-way split (train/validate/test) and **estimate your ROC AUC** validation score.
#
# Use your model to **predict probabilities** for the test set. **Get an ROC AUC test score >= 0.60.**
#
# _To earn a score of 3 for this part, get an ROC AUC test score >= 0.70 (without using the feature with leakage)._
#
#
# ### Part 3: Visualization
#
# Make visualizations for model interpretation. (You may use any libraries.) Choose two of these types:
#
# - Confusion Matrix
# - Permutation Importances
# - Partial Dependence Plot, 1 feature isolation
# - Partial Dependence Plot, 2 features interaction
# - Shapley Values
#
# _To earn a score of 3 for this part, make four of these visualization types._

# %% [markdown]
# ## Part 1: Preprocessing
#
# > You may choose which features you want to use, and whether/how you will preprocess them. If you use categorical features, you may use any tools and techniques for encoding.

# %%
train.head(35)
# Out:
#     Inspection ID  ... Fail
# 0         2088270  ...    1
# 1          555268  ...    0
# 2         1751394  ...    0
# 3         1763905  ...    0
# 4          453326  ...    0
# 5         1725221  ...    0
# 6         1981372  ...    0
# 7         1072403  ...    0
# 8         1464616  ...    1
# 9          583261  ...    1
# 10        1516695  ...    0
# 11         166332  ...    0
# 12        1982990  ...    0
# 13         635040  ...    0
# 14        1445382  ...    0
# 15        2071751  ...    0
# 16        1395548  ...    0
# 17         422255  ...    1
# 18        1464592  ...    1
# 19        1966651  ...    0
# 20         580400  ...    1
# 21        1473446  ...    0
# 22        2232615  ...    1
# 23        2151190  ...    1
# 24        1631721  ...    0
# 25        1977206  ...    1
# 26        1559966  ...    0
# 27        1989474  ...    1
# 28        2166234  ...    0
# 29         519292  ...    0
# 30        1106679  ...    1
# 31        2050053  ...    0
# 32         229287  ...    0
# 33        1493537  ...    1
# 34        2116237  ...    0
#
# [35 rows x 17 columns]

# %%
n = train["Violations"].str.split(" - ", n = 1, expand = True)

# %%
train.drop(columns =["Violations"], inplace = True)

# %%
train['Violations'] = n[0]

# %%
train['Violations'].value_counts()
# Out:
# 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED                                                                                                                                                                                                                                                                                                                                                         9362
# 33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS                                                                                                                                                                                                                                                                                                                                                          6458
# 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED                                                                                                                                                                                                                                                                                                                                    3907
# 18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS                                                                                                                                                                                                                                                                                                   3771
# 30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: CUSTOMER ADVISORY POSTED AS NEEDED                                                                                                                                                                                                                                                                                                                                                         3535
#                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS | 41. PREMISES MAINTAINED FREE OF LITTER, UNNECESSARY ARTICLES, CLEANING  EQUIPMENT PROPERLY STORED                                                                                                        1
# 2. FACILITIES TO MAINTAIN PROPER TEMPERATURE | 16. FOOD PROTECTED DURING STORAGE, PREPARATION, DISPLAY, SERVICE AND TRANSPORTATION | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED | 38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED                                                                                                                         1
# 2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE | 3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING                                                                                                                                                                                                                                                                                       1
# 3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE REQUIREMENT DURING STORAGE, PREPARATION DISPLAY AND SERVICE | 30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: CUSTOMER ADVISORY POSTED AS NEEDED                                                                                                                                                                                                                                              1
# 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED | 38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED | 40. REFRIGERATION AND METAL STEM THERMOMETERS PROVIDED AND CONSPICUOUS | 43. FOOD (ICE) DISPENSING UTENSILS, WASH CLOTHS PROPERLY STORED       1
# Name: Violations, Length: 134, dtype: int64

# %%
s = train['Violations'].str.split("|", n = 1, expand = True)

# %%
train['Violations'] = s[0]

# %%
train.head(1)
# Out:
#    Inspection ID  ...                                         Violations
# 0        2088270  ...  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...
#
# [1 rows x 17 columns]

# %%
n = test["Violations"].str.split(" - ", n = 1, expand = True)
test.drop(columns =["Violations"], inplace = True)
test['Violations'] = n[0]
test['Facility Type'].value_counts()
# Out:
# Restaurant                      11375
# Grocery Store                    2354
# School                           1348
# Children's Services Facility      287
# Daycare (2 - 6 Years)             253
#                                 ...
# NUTRITION/HERBALIFE                 1
# CONVENIENT STORE                    1
# SOCIAL CLUB                         1
# GAS STATION/RESTAURANT              1
# RETAIL                              1
# Name: Facility Type, Length: 205, dtype: int64

# %%
s = test['Violations'].str.split("|", n = 1, expand = True)
test['Violations'] = s[0]
train.head(1)
# Out:
#    Inspection ID  ...                                         Violations
# 0        2088270  ...  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...
#
# [1 rows x 17 columns]

# %%
target = 'Fail'
features = ['Facility Type', 'Risk', 'Inspection Type', 'Violations']

# %% [markdown]
# ## Part 2: Modeling
#
# > **Fit a model** with the train set. (You may use scikit-learn, xgboost, or any other library.) Use cross-validation or do a three-way split (train/validate/test) and **estimate your ROC AUC** validation score.
# >
# > Use your model to **predict probabilities** for the test set. **Get an ROC AUC test score >= 0.60.**

# %%
from sklearn.model_selection import train_test_split

train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train['Fail'], random_state=42)

# %%
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]

# %%
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer()
)

X_train_transformed = transformers.fit_transform(X_train)
X_val_transformed = transformers.transform(X_val)
X_val_transformed = pd.DataFrame(X_val_transformed, columns=X_val.columns)

rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf.fit(X_train_transformed, y_train)
print('Validation Accuracy', rf.score(X_val_transformed, y_val))
# Out:
# Validation Accuracy 0.9640062597809077

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

processor = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_processed = processor.fit_transform(X_train)
X_val_processed = processor.transform(X_val)

eval_set = [(X_train_processed, y_train), 
            (X_val_processed, y_val)]

model = XGBClassifier(n_estimators=1000, n_jobs=-1)
model.fit(X_train_processed, y_train, eval_set=eval_set, eval_metric='auc', 
          early_stopping_rounds=10)
# Out:
# [0]	validation_0-auc:0.944391	validation_1-auc:0.942663
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.949899	validation_1-auc:0.949063
# [2]	validation_0-auc:0.945635	validation_1-auc:0.944984
# [3]	validation_0-auc:0.949978	validation_1-auc:0.948808
# [4]	validation_0-auc:0.94732	validation_1-auc:0.946915
# [5]	validation_0-auc:0.951022	validation_1-auc:0.950048
# [6]	validation_0-auc:0.947173	validation_1-auc:0.946886
# [7]	validation_0-auc:0.950848	validation_1-auc:0.950087
# [8]	validation_0-auc:0.952008	validation_1-auc:0.951021
# [9]	validation_0-auc:0.957021	validation_1-auc:0.95635
# [10]	validation_0-auc:0.956946	validation_1-auc:0.956216
# [11]	validation_0-auc:0.957455	validation_1-auc:0.956581
# [12]	validation_0-auc:0.957224	validation_1-auc:0.956236
# [13]	validation_0-auc:0.957216	validation_1-auc:0.956387
# [14]	validation_0-auc:0.960364	validation_1-auc:0.95949
# [15]	validation_0-auc:0.960334	validation_1-auc:0.959477
# [16]	validation_0-auc:0.960303	validation_1-auc:0.959453
# [17]	validation_0-auc:0.959315	validation_1-auc:0.958407
# [18]	validation_0-auc:0.960362	validation_1-auc:0.959488
# [19]	validation_0-auc:0.959386	validation_1-auc:0.958505
# [20]	validation_0-auc:0.963153	validation_1-auc:0.962036
# [21]	validation_0-auc:0.96303	validation_1-auc:0.961857
# [22]	validation_0-auc:0.967719	validation_1-auc:0.966598
# [23]	validation_0-auc:0.96785	validation_1-auc:0.966671
# [24]	validation_0-auc:0.967866	validation_1-auc:0.966692
# [25]	validation_0-auc:0.970104	validation_1-auc:0.96948
# [26]	validation_0-auc:0.970037	validation_1-auc:0.969401
# [27]	validation_0-auc:0.970037	validation_1-auc:0.969401
# [28]	validation_0-auc:0.97064	validation_1-auc:0.970096
# [29]	validation_0-auc:0.970767	validation_1-auc:0.970369
# [30]	validation_0-auc:0.971428	validation_1-auc:0.971166
# [31]	validation_0-auc:0.971825	validation_1-auc:0.971147
# [32]	validation_0-auc:0.971383	validation_1-auc:0.970628
# [33]	validation_0-auc:0.97181	validation_1-auc:0.971146
# [34]	validation_0-auc:0.971349	validation_1-auc:0.970644
# [35]	validation_0-auc:0.972432	validation_1-auc:0.971515
# [36]	validation_0-auc:0.972182	validation_1-auc:0.97125
# [37]	validation_0-auc:0.971596	validation_1-auc:0.970863
# [38]	validation_0-auc:0.972272	validation_1-auc:0.971598
# [39]	validation_0-auc:0.972176	validation_1-auc:0.971461
# [40]	validation_0-auc:0.97223	validation_1-auc:0.971427
# [41]	validation_0-auc:0.972209	validation_1-auc:0.971438
# [42]	validation_0-auc:0.97368	validation_1-auc:0.972844
# [43]	validation_0-auc:0.973575	validation_1-auc:0.972849
# [44]	validation_0-auc:0.973566	validation_1-auc:0.972947
# [45]	validation_0-auc:0.974253	validation_1-auc:0.973671
# [46]	validation_0-auc:0.974284	validation_1-auc:0.973674
# [47]	validation_0-auc:0.974464	validation_1-auc:0.973858
# [48]	validation_0-auc:0.974514	validation_1-auc:0.973908
# [49]	validation_0-auc:0.974696	validation_1-auc:0.974128
# [50]	validation_0-auc:0.974766	validation_1-auc:0.974255
# [51]	validation_0-auc:0.974778	validation_1-auc:0.974214
# [52]	validation_0-auc:0.974941	validation_1-auc:0.974436
# [53]	validation_0-auc:0.975038	validation_1-auc:0.974596
# [54]	validation_0-auc:0.975555	validation_1-auc:0.975075
# [55]	validation_0-auc:0.975846	validation_1-auc:0.975282
# [56]	validation_0-auc:0.97599	validation_1-auc:0.975408
# [57]	validation_0-auc:0.976136	validation_1-auc:0.975541
# [58]	validation_0-auc:0.976286	validation_1-auc:0.97575
# [59]	validation_0-auc:0.976388	validation_1-auc:0.97588
# [60]	validation_0-auc:0.976468	validation_1-auc:0.976004
# [61]	validation_0-auc:0.977176	validation_1-auc:0.976606
# [62]	validation_0-auc:0.977386	validation_1-auc:0.976853
# [63]	validation_0-auc:0.977447	validation_1-auc:0.976938
# [64]	validation_0-auc:0.977466	validation_1-auc:0.977
# [65]	validation_0-auc:0.979448	validation_1-auc:0.978961
# [66]	validation_0-auc:0.979582	validation_1-auc:0.979091
# [67]	validation_0-auc:0.979647	validation_1-auc:0.979152
# [68]	validation_0-auc:0.979734	validation_1-auc:0.979295
# [69]	validation_0-auc:0.980165	validation_1-auc:0.979759
# [70]	validation_0-auc:0.980273	validation_1-auc:0.979873
# [71]	validation_0-auc:0.98035	validation_1-auc:0.979968
# [72]	validation_0-auc:0.980431	validation_1-auc:0.980045
# [73]	validation_0-auc:0.980482	validation_1-auc:0.980072
# [74]	validation_0-auc:0.980557	validation_1-auc:0.980088
# [75]	validation_0-auc:0.980678	validation_1-auc:0.980212
# [76]	validation_0-auc:0.980931	validation_1-auc:0.980425
# [77]	validation_0-auc:0.980987	validation_1-auc:0.980539
# [78]	validation_0-auc:0.981118	validation_1-auc:0.980704
# [79]	validation_0-auc:0.98118	validation_1-auc:0.98092
# [80]	validation_0-auc:0.981322	validation_1-auc:0.981084
# [81]	validation_0-auc:0.981443	validation_1-auc:0.981128
# [82]	validation_0-auc:0.981752	validation_1-auc:0.981407
# [83]	validation_0-auc:0.981464	validation_1-auc:0.981144
# [84]	validation_0-auc:0.98149	validation_1-auc:0.981136
# [85]	validation_0-auc:0.981703	validation_1-auc:0.981378
# [86]	validation_0-auc:0.982614	validation_1-auc:0.982294
# [87]	validation_0-auc:0.982562	validation_1-auc:0.982258
# [88]	validation_0-auc:0.982611	validation_1-auc:0.982311
# [89]	validation_0-auc:0.982682	validation_1-auc:0.982331
# [90]	validation_0-auc:0.98285	validation_1-auc:0.982518
# [91]	validation_0-auc:0.982913	validation_1-auc:0.982608
# [92]	validation_0-auc:0.983104	validation_1-auc:0.982785
# [93]	validation_0-auc:0.983302	validation_1-auc:0.983078
# [94]	validation_0-auc:0.98353	validation_1-auc:0.983294
# [95]	validation_0-auc:0.983658	validation_1-auc:0.983425
# [96]	validation_0-auc:0.983722	validation_1-auc:0.983511
# [97]	validation_0-auc:0.983914	validation_1-auc:0.983712
# [98]	validation_0-auc:0.984076	validation_1-auc:0.983846
# [99]	validation_0-auc:0.984267	validation_1-auc:0.984058
# [100]	validation_0-auc:0.984304	validation_1-auc:0.984073
# [101]	validation_0-auc:0.984318	validation_1-auc:0.984087
# [102]	validation_0-auc:0.984499	validation_1-auc:0.984237
# [103]	validation_0-auc:0.984747	validation_1-auc:0.984479
# [104]	validation_0-auc:0.984924	validation_1-auc:0.984685
# [105]	validation_0-auc:0.985039	validation_1-auc:0.98485
# [106]	validation_0-auc:0.985152	validation_1-auc:0.984951
# [107]	validation_0-auc:0.98537	validation_1-auc:0.98518
# [108]	validation_0-auc:0.985381	validation_1-auc:0.985188
# [109]	validation_0-auc:0.985397	validation_1-auc:0.985213
# [110]	validation_0-auc:0.985529	validation_1-auc:0.985284
# [111]	validation_0-auc:0.985747	validation_1-auc:0.985415
# [112]	validation_0-auc:0.985839	validation_1-auc:0.985519
# [113]	validation_0-auc:0.985918	validation_1-auc:0.985548
# [114]	validation_0-auc:0.985927	validation_1-auc:0.985604
# [115]	validation_0-auc:0.985954	validation_1-auc:0.985614
# [116]	validation_0-auc:0.985992	validation_1-auc:0.985622
# [117]	validation_0-auc:0.985978	validation_1-auc:0.985607
# [118]	validation_0-auc:0.986082	validation_1-auc:0.985677
# [119]	validation_0-auc:0.986105	validation_1-auc:0.98569
# [120]	validation_0-auc:0.986153	validation_1-auc:0.98572
# [121]	validation_0-auc:0.986169	validation_1-auc:0.98574
# [122]	validation_0-auc:0.986356	validation_1-auc:0.985918
# [123]	validation_0-auc:0.986519	validation_1-auc:0.986133
# [124]	validation_0-auc:0.986517	validation_1-auc:0.986117
# [125]	validation_0-auc:0.98659	validation_1-auc:0.986206
# [126]	validation_0-auc:0.986749	validation_1-auc:0.986488
# [127]	validation_0-auc:0.986731	validation_1-auc:0.986487
# [128]	validation_0-auc:0.986774	validation_1-auc:0.986556
# [129]	validation_0-auc:0.986794	validation_1-auc:0.986572
# [130]	validation_0-auc:0.986842	validation_1-auc:0.986584
# [131]	validation_0-auc:0.986898	validation_1-auc:0.986623
# [132]	validation_0-auc:0.986964	validation_1-auc:0.986728
# [133]	validation_0-auc:0.986973	validation_1-auc:0.986721
# [134]	validation_0-auc:0.987014	validation_1-auc:0.986747
# [135]	validation_0-auc:0.98707	validation_1-auc:0.986844
# [136]	validation_0-auc:0.987081	validation_1-auc:0.986864
# [137]	validation_0-auc:0.987157	validation_1-auc:0.98694
# [138]	validation_0-auc:0.987161	validation_1-auc:0.986939
# [139]	validation_0-auc:0.987227	validation_1-auc:0.987063
# [140]	validation_0-auc:0.98732	validation_1-auc:0.987131
# [141]	validation_0-auc:0.98733	validation_1-auc:0.987121
# [142]	validation_0-auc:0.987249	validation_1-auc:0.987108
# [143]	validation_0-auc:0.98729	validation_1-auc:0.98714
# [144]	validation_0-auc:0.987337	validation_1-auc:0.987188
# [145]	validation_0-auc:0.987418	validation_1-auc:0.987229
# [146]	validation_0-auc:0.987446	validation_1-auc:0.987282
# [147]	validation_0-auc:0.987495	validation_1-auc:0.987351
# [148]	validation_0-auc:0.987521	validation_1-auc:0.987367
# [149]	validation_0-auc:0.987568	validation_1-auc:0.987389
# [150]	validation_0-auc:0.987628	validation_1-auc:0.987433
# [151]	validation_0-auc:0.987715	validation_1-auc:0.987522
# [152]	validation_0-auc:0.987776	validation_1-auc:0.987583
# [153]	validation_0-auc:0.98776	validation_1-auc:0.987658
# [154]	validation_0-auc:0.987855	validation_1-auc:0.987659
# [155]	validation_0-auc:0.987896	validation_1-auc:0.9877
# [156]	validation_0-auc:0.987903	validation_1-auc:0.987708
# [157]	validation_0-auc:0.987902	validation_1-auc:0.987774
# [158]	validation_0-auc:0.987908	validation_1-auc:0.987754
# [159]	validation_0-auc:0.987954	validation_1-auc:0.987782
# [160]	validation_0-auc:0.987973	validation_1-auc:0.987793
# [161]	validation_0-auc:0.988001	validation_1-auc:0.987896
# [162]	validation_0-auc:0.988067	validation_1-auc:0.987963
# [163]	validation_0-auc:0.988072	validation_1-auc:0.98797
# [164]	validation_0-auc:0.988116	validation_1-auc:0.98799
# [165]	validation_0-auc:0.988097	validation_1-auc:0.988044
# [166]	validation_0-auc:0.988092	validation_1-auc:0.988026
# [167]	validation_0-auc:0.988212	validation_1-auc:0.988125
# [168]	validation_0-auc:0.988258	validation_1-auc:0.988182
# [169]	validation_0-auc:0.988246	validation_1-auc:0.987974
# [170]	validation_0-auc:0.98823	validation_1-auc:0.988011
# [171]	validation_0-auc:0.988283	validation_1-auc:0.988051
# [172]	validation_0-auc:0.988306	validation_1-auc:0.988067
# [173]	validation_0-auc:0.988339	validation_1-auc:0.988126
# [174]	validation_0-auc:0.988356	validation_1-auc:0.988129
# [175]	validation_0-auc:0.988371	validation_1-auc:0.988145
# [176]	validation_0-auc:0.988411	validation_1-auc:0.988186
# [177]	validation_0-auc:0.988451	validation_1-auc:0.988275
# [178]	validation_0-auc:0.988486	validation_1-auc:0.988357
# [179]	validation_0-auc:0.98849	validation_1-auc:0.98836
# [180]	validation_0-auc:0.988494	validation_1-auc:0.988408
# [181]	validation_0-auc:0.988531	validation_1-auc:0.988492
# [182]	validation_0-auc:0.988559	validation_1-auc:0.988517
# [183]	validation_0-auc:0.988616	validation_1-auc:0.988568
# [184]	validation_0-auc:0.988666	validation_1-auc:0.988611
# [185]	validation_0-auc:0.98868	validation_1-auc:0.988632
# [186]	validation_0-auc:0.988726	validation_1-auc:0.988672
# [187]	validation_0-auc:0.988768	validation_1-auc:0.988695
# [188]	validation_0-auc:0.988771	validation_1-auc:0.988791
# [189]	validation_0-auc:0.988784	validation_1-auc:0.988767
# [190]	validation_0-auc:0.988817	validation_1-auc:0.988803
# [191]	validation_0-auc:0.988823	validation_1-auc:0.988814
# [192]	validation_0-auc:0.988836	validation_1-auc:0.988804
# [193]	validation_0-auc:0.988834	validation_1-auc:0.988815
# [194]	validation_0-auc:0.988877	validation_1-auc:0.988849
# [195]	validation_0-auc:0.988889	validation_1-auc:0.988863
# [196]	validation_0-auc:0.988908	validation_1-auc:0.988879
# [197]	validation_0-auc:0.988894	validation_1-auc:0.988886
# [198]	validation_0-auc:0.988944	validation_1-auc:0.988969
# [199]	validation_0-auc:0.988977	validation_1-auc:0.988975
# [200]	validation_0-auc:0.988981	validation_1-auc:0.989
# [201]	validation_0-auc:0.989012	validation_1-auc:0.989028
# [202]	validation_0-auc:0.989012	validation_1-auc:0.98902
# [203]	validation_0-auc:0.989015	validation_1-auc:0.989022
# [204]	validation_0-auc:0.989017	validation_1-auc:0.989028
# [205]	validation_0-auc:0.98903	validation_1-auc:0.989068
# [206]	validation_0-auc:0.989041	validation_1-auc:0.989079
# [207]	validation_0-auc:0.989051	validation_1-auc:0.989056
# [208]	validation_0-auc:0.989093	validation_1-auc:0.989076
# [209]	validation_0-auc:0.989108	validation_1-auc:0.989082
# [210]	validation_0-auc:0.989133	validation_1-auc:0.989119
# [211]	validation_0-auc:0.989109	validation_1-auc:0.989096
# [212]	validation_0-auc:0.989117	validation_1-auc:0.989095
# [213]	validation_0-auc:0.989135	validation_1-auc:0.989123
# [214]	validation_0-auc:0.989142	validation_1-auc:0.989113
# [215]	validation_0-auc:0.989145	validation_1-auc:0.989119
# [216]	validation_0-auc:0.989147	validation_1-auc:0.98913
# [217]	validation_0-auc:0.989167	validation_1-auc:0.989151
# [218]	validation_0-auc:0.989192	validation_1-auc:0.989181
# [219]	validation_0-auc:0.989207	validation_1-auc:0.989194
# [220]	validation_0-auc:0.989228	validation_1-auc:0.989226
# [221]	validation_0-auc:0.989253	validation_1-auc:0.989257
# [222]	validation_0-auc:0.989275	validation_1-auc:0.989263
# [223]	validation_0-auc:0.989277	validation_1-auc:0.989252
# [224]	validation_0-auc:0.989317	validation_1-auc:0.989266
# [225]	validation_0-auc:0.989342	validation_1-auc:0.98929
# [226]	validation_0-auc:0.989349	validation_1-auc:0.989292
# [227]	validation_0-auc:0.98942	validation_1-auc:0.989261
# [228]	validation_0-auc:0.989446	validation_1-auc:0.989284
# [229]	validation_0-auc:0.989459	validation_1-auc:0.989308
# [230]	validation_0-auc:0.989465	validation_1-auc:0.989299
# [231]	validation_0-auc:0.989527	validation_1-auc:0.989271
# [232]	validation_0-auc:0.989547	validation_1-auc:0.989291
# [233]	validation_0-auc:0.98955	validation_1-auc:0.989262
# [234]	validation_0-auc:0.989557	validation_1-auc:0.989264
# [235]	validation_0-auc:0.989566	validation_1-auc:0.989259
# [236]	validation_0-auc:0.989593	validation_1-auc:0.98928
# [237]	validation_0-auc:0.989607	validation_1-auc:0.989286
# [238]	validation_0-auc:0.989617	validation_1-auc:0.989295
# [239]	validation_0-auc:0.989629	validation_1-auc:0.989267
# Stopping. Best iteration:
# [229]	validation_0-auc:0.989459	validation_1-auc:0.989308
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import roc_auc_score
X_test_processed = processor.transform(X_test)
class_index = 1
y_pred_proba = model.predict_proba(X_test_processed)[:, class_index]
print(f'Test ROC AUC')
print(roc_auc_score(y_test, y_pred_proba)) # Ranges from 0-1, higher is better
# Out:
# Test ROC AUC
# 0.9896730291381426

# %% [markdown]
# ## Part 3: Visualization
#
# > Make visualizations for model interpretation. (You may use any libraries.) Choose two of these types:
# >
# > - Permutation Importances
# > - Partial Dependence Plot, 1 feature isolation
# > - Partial Dependence Plot, 2 features interaction
# > - Shapley Values

# %%
# %matplotlib inline
from pdpbox.pdp import pdp_isolate, pdp_plot

feature='Risk'

encoder = transformers.named_steps['ordinalencoder']
for item in encoder.mapping:
    if item['col'] == feature:
        feature_mapping = item['mapping']
        
feature_mapping = feature_mapping[feature_mapping.index.dropna()]
category_names = feature_mapping.index.tolist()
category_codes = feature_mapping.values.tolist()

isolated = pdp_isolate(
    model=rf, 
    dataset=X_val_transformed, 
    model_features=X_val.columns, 
    feature=feature, 
    cust_grid_points=category_codes
)

fig, axes = pdp_plot(isolated, feature_name=feature, 
                     plot_lines=True, frac_to_plot=0.01)

# %%
from pdpbox.pdp import pdp_interact, pdp_interact_plot

features = ['Risk', 'Inspection Type']
years_grid = [0, 5, 10, 15, 20, 25, 30]

interaction = pdp_interact(
    model=rf, 
    dataset=X_val_transformed, 
    model_features=X_val.columns, 
    features=features, 
    cust_grid_points=[category_codes, years_grid]
)

pdp_interact_plot(interaction, plot_type='grid', feature_names=features);

# %%
from sklearn.metrics import accuracy_score

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='mean'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_val)
print('Validation Accuracy', accuracy_score(y_val, y_pred))
# Out:
# Validation Accuracy 0.9640062597809077

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import seaborn as sns

def plot_confusion_matrix(y_true, y_pred):
    labels = unique_labels(y_true)
    columns = [f'Predicted {label}' for label in labels]
    index = [f'Actual {label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), 
                         columns=columns, index=index)
    return sns.heatmap(table, annot=True, fmt='d', cmap='viridis')

plot_confusion_matrix(y_val, y_pred);
